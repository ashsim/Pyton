# %%
import json
url="https://www.youtube.com/feed/trending"
import requests
response = requests.get(url)
from BeautifulSoup import *
my_page= response.text
soup=BeautifulSoup(my_page)
a_tags=soup.findAll('a', attrs={'class':"yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink      spf-link "})
duration = soup.findAll('span', attrs={'class': 'video-time'})
name = soup.findAll('a', attrs={'class': 'g-hovercard yt-uix-sessionlink       spf-link '})
view = soup.findAll("ul", attrs={ 'class':"yt-lockup-meta-info", } ) 
x=str(view)
import re
no_tags = re.sub(r'<|>'," ",x)
views = re.findall('\s*([0-9]+\S*)\s+views\s+',no_tags)
data=[]
for i in range(len(a_tags)):
    data.append({'Title' :a_tags[i].get("title"),"URL" : "https://www.youtube.com"+a_tags[i].get('href'),'Duration':duration[i].text,"Username":name[i].text,"Views": views[i]})
from pprint import pprint
pprint(data)
with open('youtube1.json', 'w') as t:
    json.dump(data, t, sort_keys = True, indent = 4)


import unicodecsv as csv
with open('youtube2.csv', 'w') as f:

    writer = csv.writer(f)
    writer.writerow(["Title","URL","Duration","Username","Views"])
    for a in data:
        writer.writerow([a['Title'],a['URL'],a['Duration'],a['Username'],a['Views']])
# Out:
# [{'Duration': u'2:46',
#   'Title': u'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)',
#   'URL': u'https://www.youtube.com/watch?v=2QKg5SZ_35I',
#   'Username': u'Sony Pictures Entertainment',
#   'Views': '3,531,427'},
#  {'Duration': u'18:41',
#   'Title': u'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less',
#   'URL': u'https://www.youtube.com/watch?v=kFQUlA-G0N4',
#   'Username': u'CinemaSins',
#   'Views': '1,736,632'},
#  {'Duration': u'1:57',
#   'Title': u"Marvel's Inhumans - Official Trailer 1",
#   'URL': u'https://www.youtube.com/watch?v=1sYF1SXcWqQ',
#   'Username': u'Marvel Entertainment',
#   'Views': '3,742,396'},
#  {'Duration': u'2:18',
#   'Title': u'Death Note | Official Trailer [HD] | Netflix',
#   'URL': u'https://www.youtube.com/watch?v=gvxNaSIB_WI',
#   'Username': u'Netflix',
#   'Views': '1,204,514'},
#  {'Duration': u'8:46',
#   'Title': u"Trump Doesn't Seem to Know Anything About Health Care: A Closer Look",
# ...
